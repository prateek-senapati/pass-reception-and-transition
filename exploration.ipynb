# %%
from statsbombpy import sb
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
import pandas as pd

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# 69              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                      False
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 65               male              False                       True
# 66               male              False                      False
# 67             female              False                       True
# 68             female              False                       True
# 69             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2015/2016  2023-12-12T07:43:33.436182                        None
# 1    2018/2019  2023-03-07T12:20:48.118250     2021-06-13T16:17:31.694
# 2    2017/2018  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 3    2016/2017  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 4    2015/2016  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 65        2020  2023-02-24T21:26:47.128979  2023-04-27T22:38:34.970148
# 66   1988/1989  2023-06-18T19:28:39.443883     2021-06-13T16:17:31.694
# 67        2022  2023-10-24T03:36:54.066267  2023-10-24T03:37:29.085948
# 68        2023  2023-12-12T14:06:50.626363  2023-12-12T14:12:41.561162
# 69        2019  2023-07-27T10:33:48.273734     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0                         None  2023-12-12T07:43:33.436182
# 1                         None  2023-03-07T12:20:48.118250
# 2                         None  2021-01-23T21:55:30.425330
# 3                         None            2020-07-29T05:00
# 4                         None            2020-07-29T05:00
# ..                         ...                         ...
# 65  2023-04-27T22:38:34.970148  2023-02-24T21:26:47.128979
# 66                        None  2023-06-18T19:28:39.443883
# 67  2023-10-24T03:37:29.085948  2023-10-24T03:36:54.066267
# 68  2023-12-12T14:12:41.561162  2023-12-12T14:06:50.626363
# 69                        None  2023-07-27T10:33:48.273734
#
# [70 rows x 12 columns]

# %%
sb.competitions().competition_name.unique()
# Out:
# array(['1. Bundesliga', 'Champions League', 'Copa del Rey',
#        "FA Women's Super League", 'FIFA U20 World Cup', 'FIFA World Cup',
#        'Indian Super league', 'La Liga', 'Liga Profesional', 'Ligue 1',
#        'Major League Soccer', 'North American League', 'NWSL',
#        'Premier League', 'Serie A', 'UEFA Euro', 'UEFA Europa League',
#        "UEFA Women's Euro", "Women's World Cup"], dtype=object)

# %%
sb.competitions()[sb.competitions().competition_name.isin(['1. Bundesliga'])]
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0               9         27      Germany    1. Bundesliga               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2015/2016
#
#                 match_updated match_updated_360 match_available_360  \
# 0  2023-12-12T07:43:33.436182              None                None
#
#               match_available
# 0  2023-12-12T07:43:33.436182

# %%
matches = sb.matches(competition_id=9, season_id=27)
matches[(matches.home_team == 'Bayern Munich') & (matches.away_team == 'Wolfsburg')]
# Out:
#      match_id  match_date      kick_off              competition     season  \
# 263   3890305  2015-09-22  20:00:00.000  Germany - 1. Bundesliga  2015/2016
#
#          home_team  away_team  home_score  away_score match_status  ...  \
# 263  Bayern Munich  Wolfsburg           5           1    available  ...
#
#     last_updated_360 match_week competition_stage        stadium  \
# 263             None          6    Regular Season  Allianz Arena
#
#             referee           home_managers   away_managers data_version  \
# 263  Tobias Stieler  Josep Guardiola i Sala  Dieter Hecking        1.1.0
#
#     shot_fidelity_version xy_fidelity_version
# 263                     2                   2
#
# [1 rows x 22 columns]

# %%
sb.lineups(match_id=3890305)["Bayern Munich"]
# Out:
#     player_id                      player_name   player_nickname  \
# 0        5208   Thiago Alcântara do Nascimento  Thiago Alcântara
# 1        5562                    Thomas Müller              None
# 2        5570                     Manuel Neuer              None
# 3        5578                   Jérôme Boateng              None
# 4        5579                   Joshua Kimmich              None
# 5        5668               Robert Lewandowski              None
# 6        5837           Douglas Costa de Souza     Douglas Costa
# 7        8206        Arturo Erasmo Vidal Pardo      Arturo Vidal
# 8        8208                     Sven Ulreich              None
# 9        8209  Márcio Rafael Ferreira de Souza           Rafinha
# 10       8217                   Kingsley Coman              None
# 11       8220           David Olatukunbo Alaba       David Alaba
# 12       8227                      Mario Götze              None
# 13       9399          Javier Martínez Aginaga     Javi Martínez
# 14      15651              Juan Bernat Velasco       Juan Bernat
# 15      19295                     Philipp Lahm              None
# 16      20133              Xabier Alonso Olano       Xabi Alonso
# 17      22824                   Sebastian Rode              None
#
#     jersey_number  country                                              cards  \
# 0               6    Spain                                                 []
# 1              25  Germany                                                 []
# 2               1  Germany                                                 []
# 3              17  Germany                                                 []
# 4              32  Germany                                                 []
# 5               9   Poland                                                 []
# 6              11   Brazil                                                 []
# 7              23    Chile  [{'time': '81:23', 'card_type': 'Yellow Card',...
# 8              26  Germany                                                 []
# 9              13   Brazil                                                 []
# 10             29   France                                                 []
# 11             27  Austria                                                 []
# 12             19  Germany                                                 []
# 13              8    Spain                                                 []
# 14             18    Spain                                                 []
# 15             21  Germany                                                 []
# 16             14    Spain                                                 []
# 17             20  Germany                                                 []
#
#                                             positions
# 0   [{'position_id': 15, 'position': 'Left Center ...
# 1   [{'position_id': 23, 'position': 'Center Forwa...
# 2   [{'position_id': 1, 'position': 'Goalkeeper', ...
# 3   [{'position_id': 3, 'position': 'Right Center ...
# 4   [{'position_id': 11, 'position': 'Left Defensi...
# 5   [{'position_id': 23, 'position': 'Center Forwa...
# 6   [{'position_id': 17, 'position': 'Right Wing',...
# 7   [{'position_id': 13, 'position': 'Right Center...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [{'position_id': 5, 'position': 'Left Center B...
# 12  [{'position_id': 21, 'position': 'Left Wing', ...
# 13  [{'position_id': 3, 'position': 'Right Center ...
# 14  [{'position_id': 6, 'position': 'Left Back', '...
# 15  [{'position_id': 2, 'position': 'Right Back', ...
# 16  [{'position_id': 10, 'position': 'Center Defen...
# 17                                                 []

# %%
events = sb.events(match_id=3890305)

# %%
events
# Out:
#      50_50 ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                  NaN                     NaN
# 1      NaN                  NaN                     NaN
# 2      NaN                  NaN                     NaN
# 3      NaN                  NaN                     NaN
# 4      NaN                  NaN                     NaN
# ...    ...                  ...                     ...
# 4262   NaN                  NaN                     NaN
# 4263   NaN                  NaN                     NaN
# 4264   NaN                  NaN                     NaN
# 4265   NaN                  NaN                     NaN
# 4266   NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_save_block carry_end_location  \
# 0                               NaN              NaN                NaN
# 1                               NaN              NaN                NaN
# 2                               NaN              NaN                NaN
# 3                               NaN              NaN                NaN
# 4                               NaN              NaN                NaN
# ...                             ...              ...                ...
# 4262                            NaN              NaN                NaN
# 4263                            NaN              NaN                NaN
# 4264                            NaN              NaN                NaN
# 4265                            NaN              NaN                NaN
# 4266                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 0                     NaN                 NaN            NaN
# 1                     NaN                 NaN            NaN
# 2                     NaN                 NaN            NaN
# 3                     NaN                 NaN            NaN
# 4                     NaN                 NaN            NaN
# ...                   ...                 ...            ...
# 4262                  NaN                 NaN            NaN
# 4263                  NaN                 NaN            NaN
# 4264                  NaN                 NaN            NaN
# 4265                  NaN                 NaN            NaN
# 4266                  NaN                 NaN            NaN
#
#      clearance_left_foot  ... shot_technique shot_type substitution_outcome  \
# 0                    NaN  ...            NaN       NaN                  NaN
# 1                    NaN  ...            NaN       NaN                  NaN
# 2                    NaN  ...            NaN       NaN                  NaN
# 3                    NaN  ...            NaN       NaN                  NaN
# 4                    NaN  ...            NaN       NaN                  NaN
# ...                  ...  ...            ...       ...                  ...
# 4262                 NaN  ...            NaN       NaN                  NaN
# 4263                 NaN  ...            NaN       NaN                  NaN
# 4264                 NaN  ...            NaN       NaN                  NaN
# 4265                 NaN  ...            NaN       NaN                  NaN
# 4266                 NaN  ...            NaN       NaN                  NaN
#
#      substitution_replacement  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 4262                      NaN
# 4263                      NaN
# 4264                      NaN
# 4265                      NaN
# 4266                      NaN
#
#                                                 tactics           team  \
# 0     {'formation': 433, 'lineup': [{'player': {'id'...  Bayern Munich
# 1     {'formation': 442, 'lineup': [{'player': {'id'...      Wolfsburg
# 2                                                   NaN  Bayern Munich
# 3                                                   NaN      Wolfsburg
# 4                                                   NaN  Bayern Munich
# ...                                                 ...            ...
# 4262  {'formation': 442, 'lineup': [{'player': {'id'...      Wolfsburg
# 4263  {'formation': 4231, 'lineup': [{'player': {'id...  Bayern Munich
# 4264  {'formation': 4411, 'lineup': [{'player': {'id...      Wolfsburg
# 4265                                                NaN  Bayern Munich
# 4266                                                NaN      Wolfsburg
#
#      team_id     timestamp            type under_pressure
# 0        169  00:00:00.000     Starting XI            NaN
# 1        179  00:00:00.000     Starting XI            NaN
# 2        169  00:00:00.000      Half Start            NaN
# 3        179  00:00:00.000      Half Start            NaN
# 4        169  00:00:00.000      Half Start            NaN
# ...      ...           ...             ...            ...
# 4262     179  00:13:14.640  Tactical Shift            NaN
# 4263     169  00:32:36.904  Tactical Shift            NaN
# 4264     179  00:33:14.146  Tactical Shift            NaN
# 4265     169  00:15:58.728          Shield            NaN
# 4266     179  00:24:09.454          Shield           True
#
# [4267 rows x 88 columns]

# %%
events.type.unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Ball Recovery', 'Dribbled Past', 'Dribble',
#        'Dispossessed', 'Duel', 'Foul Committed', 'Foul Won',
#        'Interception', 'Block', '50/50', 'Clearance', 'Miscontrol',
#        'Shot', 'Goal Keeper', 'Error', 'Half End', 'Substitution',
#        'Tactical Shift', 'Shield'], dtype=object)

# %%
events.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_offensive',
#        'ball_recovery_recovery_failure', 'block_save_block',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'off_camera', 'out', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
#        'pass_cut_back', 'pass_end_location', 'pass_goal_assist', 'pass_height',
#        'pass_inswinging', 'pass_length', 'pass_miscommunication',
#        'pass_outcome', 'pass_outswinging', 'pass_recipient',
#        'pass_recipient_id', 'pass_shot_assist', 'pass_switch',
#        'pass_technique', 'pass_through_ball', 'pass_type', 'period',
#        'play_pattern', 'player', 'player_id', 'position', 'possession',
#        'possession_team', 'possession_team_id', 'related_events', 'second',
#        'shot_body_part', 'shot_end_location', 'shot_first_time',
#        'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one',
#        'shot_open_goal', 'shot_outcome', 'shot_statsbomb_xg', 'shot_technique',
#        'shot_type', 'substitution_outcome', 'substitution_replacement',
#        'tactics', 'team', 'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
# competition_events = sb.competition_events(
#     country="Germany",
#     division= "1. Bundesliga",
#     season="2015/2016",
#     gender="male"
# )

# competition_events

# %%
events.head()
# Out:
#   50_50 ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                  NaN                     NaN
# 1   NaN                  NaN                     NaN
# 2   NaN                  NaN                     NaN
# 3   NaN                  NaN                     NaN
# 4   NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_save_block carry_end_location  \
# 0                            NaN              NaN                NaN
# 1                            NaN              NaN                NaN
# 2                            NaN              NaN                NaN
# 3                            NaN              NaN                NaN
# 4                            NaN              NaN                NaN
#
#   clearance_aerial_won clearance_body_part clearance_head clearance_left_foot  \
# 0                  NaN                 NaN            NaN                 NaN
# 1                  NaN                 NaN            NaN                 NaN
# 2                  NaN                 NaN            NaN                 NaN
# 3                  NaN                 NaN            NaN                 NaN
# 4                  NaN                 NaN            NaN                 NaN
#
#    ... shot_technique shot_type substitution_outcome substitution_replacement  \
# 0  ...            NaN       NaN                  NaN                      NaN
# 1  ...            NaN       NaN                  NaN                      NaN
# 2  ...            NaN       NaN                  NaN                      NaN
# 3  ...            NaN       NaN                  NaN                      NaN
# 4  ...            NaN       NaN                  NaN                      NaN
#
#                                              tactics           team team_id  \
# 0  {'formation': 433, 'lineup': [{'player': {'id'...  Bayern Munich     169
# 1  {'formation': 442, 'lineup': [{'player': {'id'...      Wolfsburg     179
# 2                                                NaN  Bayern Munich     169
# 3                                                NaN      Wolfsburg     179
# 4                                                NaN  Bayern Munich     169
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
#
# [5 rows x 88 columns]

# %%
events[events.type == 'Shot'][['player', 'team', 'minute', 'second', 'shot_outcome']]
# Out:
#                          player           team  minute  second shot_outcome
# 4197     Douglas Costa de Souza  Bayern Munich       6      36        Saved
# 4198  Arturo Erasmo Vidal Pardo  Bayern Munich      12       7        Off T
# 4199              Thomas Müller  Bayern Munich      15      49        Off T
# 4200     Douglas Costa de Souza  Bayern Munich      18      19        Saved
# 4201           Daniel Caligiuri      Wolfsburg      25      48         Goal
# 4202     Douglas Costa de Souza  Bayern Munich      30      16        Saved
# 4203             Julian Draxler      Wolfsburg      32      45        Saved
# 4204          Josuha Guilavogui      Wolfsburg      37      50         Post
# 4205  Arturo Erasmo Vidal Pardo  Bayern Munich      38      57      Wayward
# 4206           Christian Träsch      Wolfsburg      48      33      Blocked
# 4207         Robert Lewandowski  Bayern Munich      50      44         Goal
# 4208         Robert Lewandowski  Bayern Munich      51      44         Goal
# 4209         Robert Lewandowski  Bayern Munich      54       3         Post
# 4210         Robert Lewandowski  Bayern Munich      54       5        Saved
# 4211         Robert Lewandowski  Bayern Munich      54       6         Goal
# 4212         Robert Lewandowski  Bayern Munich      56      26         Goal
# 4213         Robert Lewandowski  Bayern Munich      59      42         Goal
# 4214          Maximilian Arnold      Wolfsburg      64      53        Off T
# 4215                Mario Götze  Bayern Munich      67      14        Saved
# 4216              Thomas Müller  Bayern Munich      67      17        Saved
# 4217         Robert Lewandowski  Bayern Munich      68      53      Blocked
# 4218             Julian Draxler      Wolfsburg      74      20      Blocked
# 4219         Robert Lewandowski  Bayern Munich      78      54      Blocked
# 4220              Thomas Müller  Bayern Munich      87      27        Off T
# 4221          Josuha Guilavogui      Wolfsburg      89       6        Off T

# %%
# Python equivalent of SQL LIKE:

# df[df['A'].str.contains("hello")]

# %%
events[events.type == 'Ball Receipt*'][['ball_receipt_outcome']].fillna('Complete').value_counts()
# Out:
# ball_receipt_outcome
# Complete                1069
# Incomplete               160
# Name: count, dtype: int64

# %%
a = ['ball_receipt_outcome', 
       'location',  
       'player', 'player_id', 'position', 'possession',
       'possession_team', 'possession_team_id', 'related_events', 
       'team', 'team_id', 'type', 'under_pressure']

b = ['index', 'id', 'match_id', 'period', 'minute', 'second', 'timestamp']

events[(events.type == 'Ball Receipt*') & (events.position.str.contains('Midfield'))][a+b]
# Out:
#      ball_receipt_outcome      location                          player  \
# 1247                  NaN  [50.0, 32.0]             Xabier Alonso Olano
# 1248                  NaN  [50.0, 50.9]       Arturo Erasmo Vidal Pardo
# 1254                  NaN  [41.2, 60.9]               Luiz Gustavo Dias
# 1257           Incomplete  [42.8, 57.2]               Josuha Guilavogui
# 1260                  NaN   [32.1, 1.0]  Thiago Alcântara do Nascimento
# ...                   ...           ...                             ...
# 2465                  NaN  [82.4, 29.0]               Josuha Guilavogui
# 2467                  NaN  [35.1, 60.1]       Arturo Erasmo Vidal Pardo
# 2468                  NaN  [46.0, 51.5]                  Joshua Kimmich
# 2470                  NaN  [43.2, 34.0]       Arturo Erasmo Vidal Pardo
# 2473                  NaN  [64.2, 21.1]                  Joshua Kimmich
#
#       player_id                   position  possession possession_team  \
# 1247    20133.0  Center Defensive Midfield           2   Bayern Munich
# 1248     8206.0      Right Center Midfield           2   Bayern Munich
# 1254     3545.0    Left Defensive Midfield           3       Wolfsburg
# 1257     8230.0   Right Defensive Midfield           3       Wolfsburg
# 1260     5208.0       Left Center Midfield           4   Bayern Munich
# ...         ...                        ...         ...             ...
# 2465     8230.0   Right Defensive Midfield         178       Wolfsburg
# 2467     8206.0    Left Defensive Midfield         179   Bayern Munich
# 2468     5579.0   Right Defensive Midfield         179   Bayern Munich
# 2470     8206.0    Left Defensive Midfield         179   Bayern Munich
# 2473     5579.0   Right Defensive Midfield         179   Bayern Munich
#
#       possession_team_id                          related_events  \
# 1247                 169  [537dbd0c-de15-4430-b3ac-c5aa0fdc9e6d]
# 1248                 169  [867e1d58-a871-4abb-a91c-dbe498f96e96]
# 1254                 179  [fc4cc016-5750-4ba3-acf3-157b52a36c23]
# 1257                 179  [37f18bbe-f284-4eb6-94d2-5402b86d5c19]
# 1260                 169  [e0fdd74c-e1d9-4034-99a7-5504700e7b71]
# ...                  ...                                     ...
# 2465                 179  [886fc89f-f364-47e5-816a-3438ad80ecc2]
# 2467                 169  [8954ef3e-0be0-4895-a7bc-61401db4eb39]
# 2468                 169  [0457f406-2b4c-47e0-ba92-95aefd546cc5]
# 2470                 169  [6b6714b1-7c4e-49f8-a10e-7566e7657bb4]
# 2473                 169  [e39ca8a7-85a6-42c5-8969-6ca1e4e9d779]
#
#                team  team_id           type under_pressure  index  \
# 1247  Bayern Munich      169  Ball Receipt*            NaN      8
# 1248  Bayern Munich      169  Ball Receipt*            NaN     11
# 1254      Wolfsburg      179  Ball Receipt*            NaN     28
# 1257      Wolfsburg      179  Ball Receipt*            NaN     34
# 1260  Bayern Munich      169  Ball Receipt*            NaN     53
# ...             ...      ...            ...            ...    ...
# 2465      Wolfsburg      179  Ball Receipt*            NaN   4233
# 2467  Bayern Munich      169  Ball Receipt*            NaN   4239
# 2468  Bayern Munich      169  Ball Receipt*            NaN   4241
# 2470  Bayern Munich      169  Ball Receipt*            NaN   4248
# 2473  Bayern Munich      169  Ball Receipt*            NaN   4257
#
#                                         id  match_id  period  minute  second  \
# 1247  12a91213-f134-458d-834f-0d15dfe02709   3890305       1       0       3
# 1248  bc14b45f-acfe-4df3-a4a8-12c5be1a1ffd   3890305       1       0       5
# 1254  d623af6a-c946-422b-8e5e-7c3a6715bfff   3890305       1       0      28
# 1257  82e2b177-6d46-4705-aeb6-6b788cf85218   3890305       1       0      33
# 1260  7be3359c-454a-405f-b06d-4a59935202ad   3890305       1       0      47
# ...                                    ...       ...     ...     ...     ...
# 2465  ca52d97c-44b0-442f-b81e-8c0ae5048b8c   3890305       2      89       6
# 2467  453c357f-8b31-4a84-9756-c5a128f7775e   3890305       2      89      25
# 2468  8032760f-dd5a-4e70-ae3b-a20238f55c18   3890305       2      89      28
# 2470  3d0bbc62-1a4e-42e8-ae59-bfc9c731b1c5   3890305       2      89      39
# 2473  de7d6c10-c5f1-4974-9727-ad77df2f325a   3890305       2      89      47
#
#          timestamp
# 1247  00:00:03.443
# 1248  00:00:05.643
# 1254  00:00:28.969
# 1257  00:00:33.728
# 1260  00:00:47.926
# ...            ...
# 2465  00:44:06.447
# 2467  00:44:25.554
# 2468  00:44:28.695
# 2470  00:44:39.261
# 2473  00:44:47.108
#
# [420 rows x 20 columns]
