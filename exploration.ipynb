# %%
from statsbombpy import sb
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
import pandas as pd

# %%
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 65              55         43         Europe           UEFA Euro
# 66              35         75         Europe  UEFA Europa League
# 67              53        106         Europe   UEFA Women's Euro
# 68              72        107  International   Women's World Cup
# 69              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
sb.competitions().competition_name.unique()
# Out:
# array(['1. Bundesliga', 'Champions League', 'Copa del Rey',
#        "FA Women's Super League", 'FIFA U20 World Cup', 'FIFA World Cup',
#        'Indian Super league', 'La Liga', 'Liga Profesional', 'Ligue 1',
#        'Major League Soccer', 'North American League', 'NWSL',
#        'Premier League', 'Serie A', 'UEFA Euro', 'UEFA Europa League',
#        "UEFA Women's Euro", "Women's World Cup"], dtype=object)

# %%
sb.competitions()[sb.competitions().competition_name.isin(['1. Bundesliga'])]
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0               9         27      Germany    1. Bundesliga               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2015/2016
#
#                 match_updated match_updated_360 match_available_360  \
# 0  2023-12-12T07:43:33.436182              None                None
#
#               match_available
# 0  2023-12-12T07:43:33.436182

# %%
sb.matches(competition_id=9, season_id=27)
# Out:
#      match_id  match_date      kick_off              competition     season  \
# 0     3890561  2016-05-14  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 1     3890505  2016-04-02  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 2     3890511  2016-04-08  20:30:00.000  Germany - 1. Bundesliga  2015/2016
# 3     3890515  2016-04-09  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 4     3890411  2015-12-20  16:30:00.000  Germany - 1. Bundesliga  2015/2016
# ..        ...         ...           ...                      ...        ...
# 301   3890263  2015-08-15  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 302   3890262  2015-08-15  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 303   3890261  2015-08-15  18:30:00.000  Germany - 1. Bundesliga  2015/2016
# 304   3890260  2015-08-15  15:30:00.000  Germany - 1. Bundesliga  2015/2016
# 305   3890259  2015-08-14  20:30:00.000  Germany - 1. Bundesliga  2015/2016
#
# ...

# %%
sb.lineups(match_id=3890505)["Bayern Munich"]
# Out:
#     player_id                      player_name   player_nickname  \
# 0        5208   Thiago Alcântara do Nascimento  Thiago Alcântara
# 1        5562                    Thomas Müller              None
# 2        5570                     Manuel Neuer              None
# 3        5579                   Joshua Kimmich              None
# 4        5668               Robert Lewandowski              None
# 5        5837           Douglas Costa de Souza     Douglas Costa
# 6        8206        Arturo Erasmo Vidal Pardo      Arturo Vidal
# 7        8208                     Sven Ulreich              None
# 8        8209  Márcio Rafael Ferreira de Souza           Rafinha
# 9        8220           David Olatukunbo Alaba       David Alaba
# 10       8223              Franck Bilal Ribéry     Franck Ribéry
# 11       8227                      Mario Götze              None
# 12       9399          Javier Martínez Aginaga     Javi Martínez
# ...

# %%
sb.events(match_id=3890505)
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 3566   NaN                NaN                  NaN                     NaN
# 3567   NaN                NaN                  NaN                     NaN
# 3568   NaN                NaN                  NaN                     NaN
# 3569   NaN                NaN                  NaN                     NaN
# 3570   NaN                NaN                  NaN                     NaN
#
# ...

# %%
e = sb.events(match_id=3890505)
e[e.type=='Shot'].columns
# shots = e[(e.type=='Shot') & (e.shot_outcome=='Goal')][['location', 'period', 'minute', 'second', 'player', 'team', 'shot_end_location', 'shot_outcome', 'shot_statsbomb_xg', 'shot_type', 'type', 'under_pressure']]
# shots
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'injury_stoppage_in_chain', 'interception_outcome', 'location',
#        'match_id', 'minute', 'miscontrol_aerial_won', 'off_camera', 'out',
#        'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_body_part', 'pass_cross', 'pass_cut_back', 'pass_end_location',
# ...

# %%
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))

# for row in shots.itertuples():
#     if row.team == 'Bayern Munich':
#         color = 'red'
#     else:
#         color = 'black'

#     p.scatter(x=row.location[0], y=row.location[1], ax=ax, c=color, s=row.shot_statsbomb_xg*500)

p.scatter(x=20, y=0, ax=ax, c='blue', s=100)
p.scatter(x=60, y=0, ax=ax, c='black', s=100)
p.scatter(x=20, y=80, ax=ax, c='blue', s=100)
p.scatter(x=60, y=80, ax=ax, c='black', s=100)
p.scatter(x=72, y=0, ax=ax, c='red', s=100)
p.scatter(x=72, y=80, ax=ax, c='red', s=100)
p.scatter(x=72, y=0, ax=ax, c='red', s=100)
p.scatter(x=72, y=80, ax=ax, c='red', s=100)
p.scatter(x=80, y=0, ax=ax, c='yellow', s=100)
p.scatter(x=80, y=80, ax=ax, c='yellow', s=100)
# p.scatter(x=60, y=40, ax=ax, c='black', s=100)

# %%
events[events.type=="Pass"][["pass_end_location", "pass_outcome", "location", "pass_recipient", "player", "team"]].pass_outcome.unique()
# Out:
# array([nan, 'Incomplete', 'Out', 'Unknown', 'Pass Offside',
#        'Injury Clearance'], dtype=object)

# %%
events.type.unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Goal Keeper', 'Miscontrol', 'Clearance',
#        'Ball Recovery', 'Foul Committed', 'Foul Won', 'Duel',
#        'Dispossessed', 'Shot', 'Block', 'Dribble', '50/50',
#        'Interception', 'Dribbled Past', 'Injury Stoppage',
#        'Referee Ball-Drop', 'Bad Behaviour', 'Half End', 'Substitution',
#        'Tactical Shift', 'Player Off', 'Player On'], dtype=object)

# %%
sb.events(match_id=3890505, split=True, flatten_attrs=True)["passes"].columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'type',
#        'possession', 'possession_team', 'play_pattern', 'off_camera', 'team',
#        'player', 'position', 'location', 'duration', 'related_events',
#        'match_id', 'pass_recipient', 'pass_length', 'pass_angle',
#        'pass_height', 'pass_end_location', 'pass_body_part', 'pass_type',
#        'possession_team_id', 'team_id', 'player_id', 'pass_recipient_id',
#        'under_pressure', 'pass_outcome', 'pass_through_ball', 'pass_technique',
#        'pass_switch', 'pass_aerial_won', 'pass_cross', 'pass_assisted_shot_id',
#        'pass_shot_assist', 'pass_straight', 'pass_cut_back', 'pass_no_touch',
#        'counterpress', 'out', 'pass_outswinging'],
#       dtype='object')

# %%
events = sb.competition_events(
    country="Germany",
    division= "1. Bundesliga",
    season="2015/2016",
    gender="male"
)

# grouped_events = sb.competition_events(
#     country="Germany",
#     division= "1. Bundesliga",
#     season="2019/2020",
#     split=True
# )
# grouped_events["dribbles"]
# Out:
# /Users/prateek/miniconda3/envs/pass_reception_and_transition/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/prateek/miniconda3/envs/pass_reception_and_transition/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/prateek/miniconda3/envs/pass_reception_and_transition/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/prateek/miniconda3/envs/pass_reception_and_transition/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...

# %%
events
# Out:
#         50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0         NaN                NaN                  NaN                     NaN
# 1         NaN                NaN                  NaN                     NaN
# 2         NaN                NaN                  NaN                     NaN
# 3         NaN                NaN                  NaN                     NaN
# 4         NaN                NaN                  NaN                     NaN
# ...       ...                ...                  ...                     ...
# 1069861   NaN                NaN                  NaN                     NaN
# 1069862   NaN                NaN                  NaN                     NaN
# 1069863   NaN                NaN                  NaN                     NaN
# 1069864   NaN                NaN                  NaN                     NaN
# 1069865   NaN                NaN                  NaN                     NaN
#
# ...
